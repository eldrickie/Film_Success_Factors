# %%
ls
# Out:
# CONTRIBUTING.md             basics_gross_ratings.ipynb
# LICENSE.md                  student.ipynb
# README.md                   zippedData/
# awesome.gif

# %%
cd zippedData
# Out:
# /Users/eldrichvergarciadoyogan/Documents/Flatiron/Projects/Phase1Project/dsc-phase-1-project/zippedData

# %%
ls
# Out:
# Untitled.ipynb                imdb.title.principals.csv.gz
# bom.movie_gross.csv.gz        imdb.title.ratings.csv.gz
# imdb.name.basics.csv.gz       rt.movie_info.tsv.gz
# imdb.title.akas.csv.gz        rt.reviews.tsv.gz
# imdb.title.basics.csv.gz      tmdb.movies.csv.gz
# imdb.title.crew.csv.gz        tn.movie_budgets.csv.gz

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
basic_df = pd.read_csv('imdb.title.basics.csv.gz')

# %%
gross_df = pd.read_csv('bom.movie_gross.csv.gz')

# %%
ratings_df = pd.read_csv('imdb.title.ratings.csv.gz')

# %%
basic_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
basic_df.set_index('tconst', inplace=True)

# %%
basic_df.head()
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year  runtime_minutes                genres
# tconst
# tt0063540        2013            175.0    Action,Crime,Drama
# tt0066787        2019            114.0       Biography,Drama
# tt0069049        2018            122.0                 Drama
# tt0069204        2018              NaN          Comedy,Drama
# tt0100275        2017             80.0  Comedy,Drama,Fantasy

# %%
basic = basic_df.reset_index()

# %%
dup = basic.loc[basic['tconst'].duplicated() == False ]

# %%
dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 7.8+ MB

# %%
basic_df.duplicated()
# Out:
# tconst
# tt0063540    False
# tt0066787    False
# tt0069049    False
# tt0069204    False
# tt0100275    False
#              ...
# tt9916538    False
# tt9916622    False
# tt9916706    False
# tt9916730    False
# tt9916754    False
# Length: 146144, dtype: bool

# %%
gross_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
import string
punctuation = string.punctuation

# %%
[x.isalnum() for x in gross_df['title']]
# Out:
# [False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
ratings_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
ratings_df = ratings_df.set_index('tconst')

# %%
ratings_df.head()
# Out:
#             averagerating  numvotes
# tconst
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20
# tt1043726             4.2     50352
# tt1060240             6.5        21

# %%
ratings = ratings_df.reset_index()

# %%
ratings['tconst'].duplicated().value_counts()
# Out:
# False    73856
# Name: tconst, dtype: int64

# %%
basic_df.info()
gross_df.info()
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146144 entries, tt0063540 to tt9916754
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   primary_title    146144 non-null  object
#  1   original_title   146123 non-null  object
#  2   start_year       146144 non-null  int64
#  3   runtime_minutes  114405 non-null  float64
#  4   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 11.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# ...

# %%
basic_df.head()
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year  runtime_minutes                genres
# tconst
# tt0063540        2013            175.0    Action,Crime,Drama
# tt0066787        2019            114.0       Biography,Drama
# tt0069049        2018            122.0                 Drama
# tt0069204        2018              NaN          Comedy,Drama
# tt0100275        2017             80.0  Comedy,Drama,Fantasy

# %%
ratings_df.head()
# Out:
#             averagerating  numvotes
# tconst
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20
# tt1043726             4.2     50352
# tt1060240             6.5        21

# %%
basicRatings = basic_df.join(ratings_df)

# %%
basicRatings.info()
basicRatings.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146144 entries, tt0063540 to tt9916754
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   primary_title    146144 non-null  object
#  1   original_title   146123 non-null  object
#  2   start_year       146144 non-null  int64
#  3   runtime_minutes  114405 non-null  float64
#  4   genres           140736 non-null  object
#  5   averagerating    73856 non-null   float64
#  6   numvotes         73856 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 13.9+ MB
#           start_year  runtime_minutes  averagerating      numvotes
# count  146144.000000    114405.000000   73856.000000  7.385600e+04
# mean     2014.621798        86.187247       6.332729  3.523662e+03
# std         2.733583       166.360590       1.474978  3.029402e+04
# min      2010.000000         1.000000       1.000000  5.000000e+00
# ...

# %%
basicRatings.isna().value_counts()
# Out:
# primary_title  original_title  start_year  runtime_minutes  genres  averagerating  numvotes
# False          False           False       False            False   False          False       65720
#                                                                     True           True        46512
#                                            True             False   True           True        21170
#                                                                     False          False        7332
#                                                             True    True           True         2932
#                                            False            True    True           True         1653
#                                                                     False          False         516
#                                            True             True    False          False         288
# ...

# %%
fig, ax = plt.subplots(figsize = (10,10))
ax.hist(x = basicRatings['averagerating'])
# Out:
# /Users/eldrichvergarciadoyogan/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/eldrichvergarciadoyogan/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([  360.,   967.,  2616.,  5030.,  9347., 15735., 19460., 13093.,
#          6248.,  1000.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
basicRatings.set_index('primary_title', inplace = True)

# %%
gross_df.set_index('title', inplace = True)

# %%
len(gross_df)
# Out:
# 3387

# %%
basicRatings.head()
# Out:
#                                              original_title  start_year  \
# primary_title
# Sunghursh                                         Sunghursh        2013
# One Day Before the Rainy Season             Ashad Ka Ek Din        2019
# The Other Side of the Wind       The Other Side of the Wind        2018
# Sabse Bada Sukh                             Sabse Bada Sukh        2018
# The Wandering Soap Opera              La Telenovela Errante        2017
#
#                                  runtime_minutes                genres  \
# primary_title
# Sunghursh                                  175.0    Action,Crime,Drama
# One Day Before the Rainy Season            114.0       Biography,Drama
# The Other Side of the Wind                 122.0                 Drama
# Sabse Bada Sukh                              NaN          Comedy,Drama
# The Wandering Soap Opera                    80.0  Comedy,Drama,Fantasy
#
#                                  averagerating  numvotes
# primary_title
# ...

# %%
basicRatingsGross = basicRatings.join(gross_df)

# %%
basicRatingsGross.info()
basicRatingsGross.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146146 entries, !Women Art Revolution to Šiška Deluxe
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   original_title   146125 non-null  object
#  1   start_year       146146 non-null  int64
#  2   runtime_minutes  114407 non-null  float64
#  3   genres           140738 non-null  object
#  4   averagerating    73858 non-null   float64
#  5   numvotes         73858 non-null   float64
#  6   studio           3363 non-null    object
#  7   domestic_gross   3342 non-null    float64
#  8   foreign_gross    2043 non-null    object
#  9   year             3366 non-null    float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 12.3+ MB
#           start_year  runtime_minutes  averagerating      numvotes  \
# count  146146.000000    114407.000000   73858.000000  7.385800e+04
# mean     2014.621796        86.187620       6.332726  3.523584e+03
# ...

# %%
basicRatingsGross['domestic_gross'].isna().value_counts()
# Out:
# True     142804
# False      3342
# Name: domestic_gross, dtype: int64

# %%
basicRatingsGross.loc[basicRatingsGross['domestic_gross'].isna() == False]
# Out:
#                                     original_title  start_year  \
# '71                                            '71        2014
# 1,000 Times Good Night       Tusen ganger god natt        2013
# 10 Cloverfield Lane            10 Cloverfield Lane        2016
# 10 Years                                  10 Years        2011
# 1001 Grams                               1001 Gram        2014
# ...                                            ...         ...
# Zindagi Na Milegi Dobara  Zindagi Na Milegi Dobara        2011
# Zombeavers                              Zombeavers        2014
# Zookeeper                                Zookeeper        2011
# Zoolander 2                            Zoolander 2        2016
# Zootopia                                  Zootopia        2016
#
#                           runtime_minutes                      genres  \
# '71                                  99.0       Action,Drama,Thriller
# ...

# %%
basicRatingsGross.loc[basicRatingsGross['original_title'].duplicated() == True]
#drop the duplicates
# Out:
#                                                                 original_title  \
# #5                                                                          #5
# (aguirre)                                                            (aguirre)
# 1                                                                            1
# 1                                                                            1
# 10                                                                          10
# ...                                                                        ...
# Ângelo de Sousa - Tudo o Que Sou Capaz  Ângelo de Sousa - Tudo o Que Sou Capaz
# Çagrilan                                                              Çagrilan
# Éden                                                                      Éden
# Ódio                                                                      Ódio
# Ümmü Sibyan: Zifir                                          Ümmü Sibyan: Zifir
#
# ...

# %%
basicRatingsGross['original_title'].drop_duplicates(inplace = True)

# %%
len(basicRatingsGross)
# Out:
# 146146

# %%
basicRatingsGross = basicRatingsGross.loc[basicRatingsGross['domestic_gross'].isna() == False]

# %%
len(basicRatingsGross)
# Out:
# 3342

# %%
basicRatingsGross
# Out:
#                                     original_title  start_year  \
# '71                                            '71        2014
# 1,000 Times Good Night       Tusen ganger god natt        2013
# 10 Cloverfield Lane            10 Cloverfield Lane        2016
# 10 Years                                  10 Years        2011
# 1001 Grams                               1001 Gram        2014
# ...                                            ...         ...
# Zindagi Na Milegi Dobara  Zindagi Na Milegi Dobara        2011
# Zombeavers                              Zombeavers        2014
# Zookeeper                                Zookeeper        2011
# Zoolander 2                            Zoolander 2        2016
# Zootopia                                  Zootopia        2016
#
#                           runtime_minutes                      genres  \
# '71                                  99.0       Action,Drama,Thriller
# ...

# %%
basicRatingsGross.loc[basicRatingsGross['foreign_gross'].isna() == True]
# Out:
#                                     original_title  start_year  \
# 1,000 Times Good Night       Tusen ganger god natt        2013
# 10 Years                                  10 Years        2011
# 1001 Grams                               1001 Gram        2014
# 13 Sins                                    13 Sins        2014
# 1911                               Xin hai ge ming        2011
# ...                                            ...         ...
# Youth                                     Fang hua        2017
# Z for Zachariah                    Z for Zachariah        2015
# Zero Motivation               Efes beyahasei enosh        2014
# Zindagi Na Milegi Dobara  Zindagi Na Milegi Dobara        2011
# Zombeavers                              Zombeavers        2014
#
#                           runtime_minutes                   genres  \
# 1,000 Times Good Night              117.0                Drama,War
# 10 Years                            100.0     Comedy,Drama,Romance
# ...

# %%
basicRatingsGross['domestic_gross'].mean()
# Out:
# 29865596.8818073

# %%
foreign_gross = basicRatingsGross.loc[basicRatingsGross['foreign_gross'].isna() == False]

# %%
len(foreign_gross)
# Out:
# 2019

# %%
for x in foreign_gross['foreign_gross']:
    print(type(x))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
foreign_gross['foreign_gross'] = foreign_gross['foreign_gross'].str.replace(',', "").astype(float)
# Out:
# <ipython-input-49-9bb29d93650f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   foreign_gross['foreign_gross'] = foreign_gross['foreign_gross'].str.replace(',', "").astype(float)

# %%
foreign_gross['foreign_gross']
# Out:
# '71                       355000.0
# 10 Cloverfield Lane     38100000.0
# 102 Not Out             10900000.0
# 11-11-11                 5700000.0
# 12 Strong               21600000.0
#                           ...
# Yves Saint Laurent      20300000.0
# Zero Dark Thirty        37100000.0
# Zookeeper               89500000.0
# Zoolander 2             27900000.0
# Zootopia               682500000.0
# Name: foreign_gross, Length: 2019, dtype: float64

# %%
foreign_gross.loc[foreign_gross['domestic_gross'] <= foreign_gross['foreign_gross']]
# Out:
#                             original_title  start_year  runtime_minutes  \
# 102 Not Out                    102 Not Out        2018            102.0
# 11-11-11                          11-11-11        2011             90.0
# 12 Years a Slave          12 Years a Slave        2013            134.0
# 127 Hours                        127 Hours        2010             94.0
# 13 Assassins          Jûsan-nin no shikaku        2010            141.0
# ...                                    ...         ...              ...
# Young Goethe in Love               Goethe!        2010            102.0
# Your Name.                  Kimi no na wa.        2016            106.0
# Yves Saint Laurent      Yves Saint Laurent        2014            106.0
# Zookeeper                        Zookeeper        2011            102.0
# Zootopia                          Zootopia        2016            108.0
#
#                                           genres  averagerating  numvotes  \
# ...

# %%
foreign_gross['foreign_gross'].mean()
# Out:
# 75300106.95685983

# %%
foreign = foreign_gross['foreign_gross'].mean()

# %%
basicRatingsGross.loc[basicRatingsGross['foreign_gross'].isna() == False]['domestic_gross'].mean()
# Out:
# 48277450.76027737

# %%
domestic = basicRatingsGross.loc[basicRatingsGross['foreign_gross'].isna() == False]['domestic_gross'].mean()

# %%
basicRatingsGross.loc[basicRatingsGross['foreign_gross'].isna() == True]
# Out:
#                                     original_title  start_year  \
# 1,000 Times Good Night       Tusen ganger god natt        2013
# 10 Years                                  10 Years        2011
# 1001 Grams                               1001 Gram        2014
# 13 Sins                                    13 Sins        2014
# 1911                               Xin hai ge ming        2011
# ...                                            ...         ...
# Youth                                     Fang hua        2017
# Z for Zachariah                    Z for Zachariah        2015
# Zero Motivation               Efes beyahasei enosh        2014
# Zindagi Na Milegi Dobara  Zindagi Na Milegi Dobara        2011
# Zombeavers                              Zombeavers        2014
#
#                           runtime_minutes                   genres  \
# 1,000 Times Good Night              117.0                Drama,War
# 10 Years                            100.0     Comedy,Drama,Romance
# ...

# %%
#getting the ration between mean domestic gross and mean foreign gross
ratio = foreign / domestic
ratio
# Out:
# 1.5597366010637967

# %%
basicRatingsGross['foreign_gross'].fillna(basicRatingsGross['domestic_gross'] * ratio, inplace = True)

# %%
basicRatingsGross
# Out:
#                                     original_title  start_year  \
# '71                                            '71        2014
# 1,000 Times Good Night       Tusen ganger god natt        2013
# 10 Cloverfield Lane            10 Cloverfield Lane        2016
# 10 Years                                  10 Years        2011
# 1001 Grams                               1001 Gram        2014
# ...                                            ...         ...
# Zindagi Na Milegi Dobara  Zindagi Na Milegi Dobara        2011
# Zombeavers                              Zombeavers        2014
# Zookeeper                                Zookeeper        2011
# Zoolander 2                            Zoolander 2        2016
# Zootopia                                  Zootopia        2016
#
#                           runtime_minutes                      genres  \
# '71                                  99.0       Action,Drama,Thriller
# ...

# %%
basicRatingsGross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3342 entries, '71 to Zootopia
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   original_title   3342 non-null   object
#  1   start_year       3342 non-null   int64
#  2   runtime_minutes  3175 non-null   float64
#  3   genres           3302 non-null   object
#  4   averagerating    3005 non-null   float64
#  5   numvotes         3005 non-null   float64
#  6   studio           3341 non-null   object
#  7   domestic_gross   3342 non-null   float64
#  8   foreign_gross    3342 non-null   object
#  9   year             3342 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 367.2+ KB

# %%
basicRatingsGross['foreign_gross'] = basicRatingsGross['foreign_gross'].str.replace(',', "").astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0161fa15e77e> in <module>
# ----> 1 basicRatingsGross['foreign_gross'] = basicRatingsGross['foreign_gross'].str.replace(',', "").astype(float)
#
# NameError: name 'basicRatingsGross' is not defined

# %%
basicRatingsGross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3342 entries, '71 to Zootopia
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   original_title   3342 non-null   object
#  1   start_year       3342 non-null   int64
#  2   runtime_minutes  3175 non-null   float64
#  3   genres           3302 non-null   object
#  4   averagerating    3005 non-null   float64
#  5   numvotes         3005 non-null   float64
#  6   studio           3341 non-null   object
#  7   domestic_gross   3342 non-null   float64
#  8   foreign_gross    2019 non-null   float64
#  9   year             3342 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 367.2+ KB

# %%
basicRatingsGross['foreign_gross'] = round(basicRatingsGross['foreign_gross'])

# %%
basicRatingsGross['total_gross'] = round(basicRatingsGross['domestic_gross'] + basicRatingsGross['foreign_gross'])

# %%
basicRatingsGross
# Out:
#                                     original_title  start_year  \
# '71                                            '71        2014
# 1,000 Times Good Night       Tusen ganger god natt        2013
# 10 Cloverfield Lane            10 Cloverfield Lane        2016
# 10 Years                                  10 Years        2011
# 1001 Grams                               1001 Gram        2014
# ...                                            ...         ...
# Zindagi Na Milegi Dobara  Zindagi Na Milegi Dobara        2011
# Zombeavers                              Zombeavers        2014
# Zookeeper                                Zookeeper        2011
# Zoolander 2                            Zoolander 2        2016
# Zootopia                                  Zootopia        2016
#
#                           runtime_minutes                      genres  \
# '71                                  99.0       Action,Drama,Thriller
# ...

# %%
basicRatingsGross.groupby(['runtime_minutes']).mean()
# Out:
#                   start_year  averagerating  numvotes  domestic_gross  \
# runtime_minutes
# 2.0              2017.000000            NaN       NaN        177000.0
# 3.0              2015.000000            6.7      10.0      48350000.0
# 4.0              2018.000000            NaN       NaN      56500000.0
# 5.0              2015.500000            NaN       NaN      17203250.0
# 6.0              2016.666667            NaN       NaN       1444000.0
# ...                      ...            ...       ...             ...
# 186.0            2013.000000            8.2   54802.0       1600000.0
# 189.0            2018.000000            7.7    4758.0       1300000.0
# 192.0            2014.000000            8.7    1347.0        757000.0
# 272.0            2010.000000            7.5    2928.0        111000.0
# 623.0            2017.000000            NaN       NaN       2300000.0
#
#                  foreign_gross         year   total_gross
# runtime_minutes
# ...

# %%
basicRatingsGross
# Out:
#                                     original_title  start_year  \
# '71                                            '71        2014
# 1,000 Times Good Night       Tusen ganger god natt        2013
# 10 Cloverfield Lane            10 Cloverfield Lane        2016
# 10 Years                                  10 Years        2011
# 1001 Grams                               1001 Gram        2014
# ...                                            ...         ...
# Zindagi Na Milegi Dobara  Zindagi Na Milegi Dobara        2011
# Zombeavers                              Zombeavers        2014
# Zookeeper                                Zookeeper        2011
# Zoolander 2                            Zoolander 2        2016
# Zootopia                                  Zootopia        2016
#
#                           runtime_minutes                      genres  \
# '71                                  99.0       Action,Drama,Thriller
# ...
